# %% [markdown]
# <a href="https://colab.research.google.com/github/2024bijayashrestha/2024datascience/blob/main/Day2_Test2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Second Day

# %% [markdown]
# # Second Day

# %% [markdown]
# second *Day*

# %% [markdown]
# ```
# # This is formatted as code
#
# for i in list:
#   print (i)
#
# ```

# %% [markdown]
# ![OIP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# [google](https://www.google.com/)

# %% [markdown]
# 1.  Data Science
# 2.  Machine Larning
# 3.  Neural Network

# %% [markdown]
# ---

# %% [markdown]
# N9 is the best institution for IT training

# %% [markdown]
# $x1 =\frac {a}{b}$

# %% [markdown]
# $ ax^2 + bx + c = 0 $

# %% [markdown]
# $ x1=\frac{-b+\sqrt(b^2-4ac)}{2a}$
